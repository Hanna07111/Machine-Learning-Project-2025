# %% [markdown]
# ### 데이터 불러오기

# %%
import pandas as pd

train = pd.read_csv("/content/drive/MyDrive/Coursework/25-2 Machine Learning/Project/DataPreprocessing_final/openworld_train.csv")
test = pd.read_csv("/content/drive/MyDrive/Coursework/25-2 Machine Learning/Project/DataPreprocessing_final/openworld_test.csv")

y_train = train['label']
X_train = train.drop(columns=['label'])

y_test = test['label']
X_test = test.drop(columns=['label'])

print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (20300, 26)
# y_train shape: (20300,)
# X_test shape: (8700, 26)
# y_test shape: (8700,)

# %%
# validation set 분리
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42, stratify=y_train
)

#이진 분류 라벨 생성
y_tr_bin = (y_train != 95).astype(int)
y_val_bin = (y_val != 95).astype(int)
y_test_bin = (y_test != 95).astype(int)

# %% [markdown]
# ### xgboost 임포트

# %%
import numpy as np
import pandas as pd
from xgboost import XGBClassifier, callback
from sklearn.metrics import (
    classification_report, confusion_matrix, roc_auc_score,
    roc_curve, average_precision_score, precision_recall_curve, accuracy_score, f1_score
)

# %% [markdown]
# ### 클래스 불균형 대응

# %%
# 양성=1, 음성=0 가정
pos = (y_tr_bin == 1).sum()
neg = (y_val_bin == 0).sum()
scale_pos_weight = neg / max(pos, 1)   # pos=0 보호

print(f"pos={pos}, neg={neg}, scale_pos_weight={scale_pos_weight:.2f}")
# Out:
# pos=8512, neg=1120, scale_pos_weight=0.13

# %% [markdown]
# ### 베이스라인 학습

# %%
xgb = XGBClassifier(
    n_estimators=2000,
    learning_rate=0.03,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    min_child_weight=1.0,
    reg_lambda=1.0,
    reg_alpha=0.0,
    tree_method="hist",
    random_state=42,
    n_jobs=-1,
    scale_pos_weight=scale_pos_weight,
    eval_metric=["aucpr","auc", "logloss"],
    early_stopping_rounds = 100
)

xgb.fit(
    X_train, y_tr_bin,
    eval_set=[(X_train, y_tr_bin), (X_val, y_val_bin)],
    verbose=50
)
# Out:
# [0]	validation_0-aucpr:0.91880	validation_0-auc:0.85696	validation_0-logloss:1.02824	validation_1-aucpr:0.91900	validation_1-auc:0.85792	validation_1-logloss:1.02792
# [50]	validation_0-aucpr:0.95568	validation_0-auc:0.91859	validation_0-logloss:0.66163	validation_1-aucpr:0.94673	validation_1-auc:0.90348	validation_1-logloss:0.66850
# [100]	validation_0-aucpr:0.96407	validation_0-auc:0.93385	validation_0-logloss:0.56972	validation_1-aucpr:0.95304	validation_1-auc:0.91555	validation_1-logloss:0.58313
# [150]	validation_0-aucpr:0.97066	validation_0-auc:0.94537	validation_0-logloss:0.51512	validation_1-aucpr:0.95752	validation_1-auc:0.92376	validation_1-logloss:0.53554
# [200]	validation_0-aucpr:0.97606	validation_0-auc:0.95482	validation_0-logloss:0.47148	validation_1-aucpr:0.96111	validation_1-auc:0.93044	validation_1-logloss:0.49948
# [250]	validation_0-aucpr:0.97990	validation_0-auc:0.96163	validation_0-logloss:0.43808	validation_1-aucpr:0.96305	validation_1-auc:0.93393	validation_1-logloss:0.47464
# [300]	validation_0-aucpr:0.98303	validation_0-auc:0.96721	validation_0-logloss:0.40947	validation_1-aucpr:0.96443	validation_1-auc:0.93656	validation_1-logloss:0.45472
# [350]	validation_0-aucpr:0.98533	validation_0-auc:0.97145	validation_0-logloss:0.38592	validation_1-aucpr:0.96565	validation_1-auc:0.93880	validation_1-logloss:0.43822
# [400]	validation_0-aucpr:0.98725	validation_0-auc:0.97498	validation_0-logloss:0.36695	validation_1-aucpr:0.96656	validation_1-auc:0.94045	validation_1-logloss:0.42590
# [450]	validation_0-aucpr:0.98909	validation_0-auc:0.97845	validation_0-logloss:0.34661	validation_1-aucpr:0.96729	validation_1-auc:0.94189	validation_1-logloss:0.41278
# [500]	validation_0-aucpr:0.99054	validation_0-auc:0.98118	validation_0-logloss:0.32984	validation_1-aucpr:0.96769	validation_1-auc:0.94270	validation_1-logloss:0.40296
# [550]	validation_0-aucpr:0.99165	validation_0-auc:0.98333	validation_0-logloss:0.31568	validation_1-aucpr:0.96820	validation_1-auc:0.94359	validation_1-logloss:0.39383
# [600]	validation_0-aucpr:0.99288	validation_0-auc:0.98572	validation_0-logloss:0.29887	validation_1-aucpr:0.96891	validation_1-auc:0.94485	validation_1-logloss:0.38313
# [650]	validation_0-aucpr:0.99378	validation_0-auc:0.98747	validation_0-logloss:0.28619	validation_1-aucpr:0.96934	validation_1-auc:0.94554	validation_1-logloss:0.37599
# [700]	validation_0-aucpr:0.99462	validation_0-auc:0.98914	validation_0-logloss:0.27354	validation_1-aucpr:0.96966	validation_1-auc:0.94611	validation_1-logloss:0.36902
# [750]	validation_0-aucpr:0.99537	validation_0-auc:0.99063	validation_0-logloss:0.26139	validation_1-aucpr:0.96999	validation_1-auc:0.94669	validation_1-logloss:0.36214
# [800]	validation_0-aucpr:0.99607	validation_0-auc:0.99203	validation_0-logloss:0.24863	validation_1-aucpr:0.97024	validation_1-auc:0.94710	validation_1-logloss:0.35553
# [850]	validation_0-aucpr:0.99659	validation_0-auc:0.99306	validation_0-logloss:0.23845	validation_1-aucpr:0.97050	validation_1-auc:0.94762	validation_1-logloss:0.34976
# [900]	validation_0-aucpr:0.99705	validation_0-auc:0.99399	validation_0-logloss:0.22879	validation_1-aucpr:0.97085	validation_1-auc:0.94815	validation_1-logloss:0.34441
# [950]	validation_0-aucpr:0.99743	validation_0-auc:0.99475	validation_0-logloss:0.22009	validation_1-aucpr:0.97111	validation_1-auc:0.94864	validation_1-logloss:0.33931
# [1000]	validation_0-aucpr:0.99774	validation_0-auc:0.99539	validation_0-logloss:0.21197	validation_1-aucpr:0.97126	validation_1-auc:0.94897	validation_1-logloss:0.33513
# [1050]	validation_0-aucpr:0.99803	validation_0-auc:0.99597	validation_0-logloss:0.20416	validation_1-aucpr:0.97146	validation_1-auc:0.94933	validation_1-logloss:0.33105
# [1100]	validation_0-aucpr:0.99831	validation_0-auc:0.99653	validation_0-logloss:0.19671	validation_1-aucpr:0.97167	validation_1-auc:0.94965	validation_1-logloss:0.32739
# [1150]	validation_0-aucpr:0.99855	validation_0-auc:0.99703	validation_0-logloss:0.18923	validation_1-aucpr:0.97181	validation_1-auc:0.94989	validation_1-logloss:0.32377
# [1200]	validation_0-aucpr:0.99876	validation_0-auc:0.99745	validation_0-logloss:0.18241	validation_1-aucpr:0.97195	validation_1-auc:0.95014	validation_1-logloss:0.32053
# [1250]	validation_0-aucpr:0.99891	validation_0-auc:0.99777	validation_0-logloss:0.17583	validation_1-aucpr:0.97222	validation_1-auc:0.95056	validation_1-logloss:0.31696
# [1300]	validation_0-aucpr:0.99908	validation_0-auc:0.99810	validation_0-logloss:0.16886	validation_1-aucpr:0.97227	validation_1-auc:0.95063	validation_1-logloss:0.31424
# [1350]	validation_0-aucpr:0.99921	validation_0-auc:0.99837	validation_0-logloss:0.16254	validation_1-aucpr:0.97242	validation_1-auc:0.95088	validation_1-logloss:0.31122
# [1400]	validation_0-aucpr:0.99931	validation_0-auc:0.99859	validation_0-logloss:0.15753	validation_1-aucpr:0.97255	validation_1-auc:0.95109	validation_1-logloss:0.30912
# [1450]	validation_0-aucpr:0.99941	validation_0-auc:0.99878	validation_0-logloss:0.15257	validation_1-aucpr:0.97254	validation_1-auc:0.95109	validation_1-logloss:0.30750
# [1500]	validation_0-aucpr:0.99948	validation_0-auc:0.99892	validation_0-logloss:0.14822	validation_1-aucpr:0.97263	validation_1-auc:0.95126	validation_1-logloss:0.30595
# [1550]	validation_0-aucpr:0.99955	validation_0-auc:0.99907	validation_0-logloss:0.14324	validation_1-aucpr:0.97273	validation_1-auc:0.95148	validation_1-logloss:0.30364
# [1600]	validation_0-aucpr:0.99961	validation_0-auc:0.99920	validation_0-logloss:0.13840	validation_1-aucpr:0.97276	validation_1-auc:0.95156	validation_1-logloss:0.30181
# [1650]	validation_0-aucpr:0.99966	validation_0-auc:0.99930	validation_0-logloss:0.13415	validation_1-aucpr:0.97286	validation_1-auc:0.95173	validation_1-logloss:0.30001
# [1700]	validation_0-aucpr:0.99970	validation_0-auc:0.99938	validation_0-logloss:0.12979	validation_1-aucpr:0.97283	validation_1-auc:0.95174	validation_1-logloss:0.29879
# [1750]	validation_0-aucpr:0.99974	validation_0-auc:0.99946	validation_0-logloss:0.12549	validation_1-aucpr:0.97282	validation_1-auc:0.95170	validation_1-logloss:0.29761
# [1800]	validation_0-aucpr:0.99977	validation_0-auc:0.99953	validation_0-logloss:0.12208	validation_1-aucpr:0.97287	validation_1-auc:0.95180	validation_1-logloss:0.29652
# [1850]	validation_0-aucpr:0.99981	validation_0-auc:0.99960	validation_0-logloss:0.11846	validation_1-aucpr:0.97295	validation_1-auc:0.95193	validation_1-logloss:0.29516
# [1900]	validation_0-aucpr:0.99983	validation_0-auc:0.99964	validation_0-logloss:0.11498	validation_1-aucpr:0.97308	validation_1-auc:0.95219	validation_1-logloss:0.29333
# [1950]	validation_0-aucpr:0.99985	validation_0-auc:0.99969	validation_0-logloss:0.11183	validation_1-aucpr:0.97301	validation_1-auc:0.95205	validation_1-logloss:0.29307
# [1999]	validation_0-aucpr:0.99987	validation_0-auc:0.99972	validation_0-logloss:0.10863	validation_1-aucpr:0.97309	validation_1-auc:0.95218	validation_1-logloss:0.29185
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=100,
#               enable_categorical=False, eval_metric=['aucpr', 'auc', 'logloss'],
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.03, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=1.0, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=2000, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %% [markdown]
# ### 예측

# %%
y_pred = xgb.predict(X_test)
y_prob = xgb.predict_proba(X_test)[:,1]

# ==== Accuracy ====
accuracy = accuracy_score(y_test_bin, y_pred)

# ==== F1 ====
f1_macro = f1_score(y_test_bin, y_pred, average='macro')
f1_micro = f1_score(y_test_bin, y_pred, average='micro')
f1_weighted = f1_score(y_test_bin, y_pred, average='weighted')

# ==== ROC-AUC ====
roc_auc = roc_auc_score(y_test_bin, y_prob)

# ==== PR-AUC ====
pr_auc = average_precision_score(y_test_bin, y_prob, average='macro')

# ==== Classification report ====
report = classification_report(y_test_bin, y_pred)

print("Accuracy:", accuracy)
print("F1-macro:", f1_macro)
print("F1-micro:", f1_micro)
print("F1-weighted:", f1_weighted)
print("ROC-AUC:", roc_auc)
print("PR-AUC:", pr_auc)
print(report)
# Out:
# Accuracy: 0.8801149425287357
# F1-macro: 0.8714478528238355
# F1-micro: 0.8801149425287357
# F1-weighted: 0.881806924184274
# ROC-AUC: 0.9568333333333333
# PR-AUC: 0.9760184133116043
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84      3000
#            1       0.94      0.87      0.90      5700
#
#     accuracy                           0.88      8700
#    macro avg       0.86      0.88      0.87      8700
# weighted avg       0.89      0.88      0.88      8700
